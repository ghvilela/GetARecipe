# %%
import csv

recipes_dict = csv.DictReader(open("C:/Users/BH/Desktop/GetARecipe/data/recipes_sample.csv"))
for line in recipes_dict:
    print (line)
# Out:
# {'id': '192281', 'name': 'southern butter mints', 'minutes': '15', 'steps': "['melt cream cheese and butter in large saucepan over low heat , stirring constantly until smooth', 'gradually stir in powdered sugar', 'add peppermint and vanilla extracts , stirring until well blended', 'divide cream cheese mixture into 10 portions', 'roll each into a 12-inch rope', 'cut into 1 / 2-inch pieces', 'let stand , uncovered , 4 hours or until firm']", 'ingredients': "['cream cheese', 'butter', 'powdered sugar', 'peppermint extract', 'vanilla extract']"}
# ...
